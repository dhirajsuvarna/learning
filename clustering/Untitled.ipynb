# %% [markdown]
# # Clustering

# %%
import numpy as np
from matplotlib import pyplot as plt

from sklearn.datasets import make_blobs

# %%
n_samples = 1500
random_state = 23
X, y = make_blobs(n_samples= n_samples, random_state = random_state)

# %%
print(X.shape, y.shape)
# Out:
# (1500, 2) (1500,)

# %%
X
# Out:
# array([[ 3.82081566, -3.90107545],
#        [-4.8812111 ,  3.84791015],
#        [-6.37820028,  3.2332313 ],
#        ...,
#        [ 1.73621834,  9.71254698],
#        [-5.37500639,  2.6108098 ],
#        [-0.26622294,  8.20240996]])

# %%
y
# Out:
# array([1, 2, 2, ..., 0, 2, 0])

# %%
plt.scatter(X[:, 0], X[:, 1])

# %% [markdown]
# ## KMeans Algorithm

# %%
from sklearn.cluster import KMeans

kmeans_result = KMeans(n_clusters = 3, init='k-means++').fit(X)

# %%
kmeans_result.cluster_centers_, kmeans_result.labels_, kmeans_result.inertia_, kmeans_result.n_iter_
# Out:
# (array([[ 5.29884081, -4.3505235 ],
#         [ 0.25144148,  8.90066736],
#         [-5.66878002,  3.68344882]]),
#  array([0, 2, 2, ..., 1, 2, 1]),
#  3021.4965956574633,
#  2)

# %%
plt.scatter(X[:, 0], X[:, 1], c=kmeans_result.labels_)

# %% [markdown]
# ### Determine the Number of clusters: Elbow Method

# %% [markdown]
# ### Evaluate the quality of Clustering: Sillutote Method

# %% [markdown]
# ## K-Medoids

# %%
# install pip install scikit-learn-extra
from sklearn_extra.cluster import KMedoids

kmedoids = KMedoids(n_clusters=3, method='pam', init='k-medoids++').fit(X)

# %%
kmedoids.cluster_centers_, kmedoids.medoid_indices_, kmedoids.labels_, kmedoids.inertia_
# Out:
# (array([[ 5.28267655, -4.34600286],
#         [ 0.27463375,  8.8938145 ],
#         [-5.57994147,  3.61975719]]),
#  array([ 433, 1186,  519]),
#  array([0, 2, 2, ..., 1, 2, 1], dtype=int64),
#  1888.1336473728945)

# %%
plt.scatter(X[:,0], X[:, 1], c=kmedoids.labels_)

# %%
transformation = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X_aniso = np.dot(X, transformation)

# %%
plt.scatter(X_aniso[:, 0], X_aniso[:, 1])

# %%
X_varied, y_varied = make_blobs(n_samples=n_samples,
                                cluster_std=[1.0, 2.5, 0.5],
                                random_state=random_state)

# %%
plt.scatter(X_varied[:, 0], X_varied[:, 1])

# %%
X_filtered = np.vstack((X[y == 0][:500], X[y == 1][:100], X[y == 2][:10]))

# %%
plt.scatter(X_filtered[:, 0], X_filtered[:, 1])
